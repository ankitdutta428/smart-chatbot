# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/training-data-for-multiability-chabot/final_training_data.csv

# %%
# !pip install -q -U transformers
# !pip install -q -U accelarate
# !pip install -q -U bitsandbytes
# !pip install -q -U trl
# !pip install -q -U peft
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 98.2 MB/s eta 0:00:00:00:0100:01
# ERROR: Could not find a version that satisfies the requirement accelarate (from versions: none)
# ERROR: No matching distribution found for accelarate
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 25.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.4/293.4 kB 11.9 MB/s eta 0:00:00

# %%
model_name = "microsoft/Phi-3-mini-4k-instruct"
dataset_path = "/kaggle/input/training-data-for-multiability-chabot/final_training_data.csv"

# %%
import os
import warnings
import pandas as pd 
import numpy as np 
import torch 
import torch.nn as nn

from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, TrainingArguments, pipeline, logging
from peft import LoraConfig, PeftConfig
from trl import SFTTrainer, setup_chat_format

# %%
data = pd.read_csv('/kaggle/input/training-data-for-multiability-chabot/final_training_data.csv')

# %%
data.head(10)
# Out:
#    Unnamed: 0                                             prompt  \
# 0         240  Hi doctor,I am just wondering what is abutting...
# 1         620  Hello doctor, I have a stiffness of neck and p...
# 2        1208  Hi doctor, I am a 26 year old male. I am 5 fee...
# 3        1388  Hi doctor, I am a 26 year old male. I am 5 fee...
# 4        1828  Hello doctor, I am a 24-year-old male. I am af...
# 5        1855  Hello doctor, I had a sudden weight gain. Are ...
# 6        2738  Hi doctor, I am 22 years old. I have been faci...
# 7        3048  Hello doctor, My friend aged 30 had two drops ...
# 8        3272  Hello doctor, I had symptoms of cold, cough an...
# 9        3404  Hi doctor, I am a lactating mother. I feel diz...
#
#                                             response category  category_id
# 0  Hi. I have gone through your query with dilige...       HC            0
# 1  Hello. From your symptoms, it seems like fibro...       HC            0
# 2  Hello. I have gone through your information an...       HC            0
# 3  Hello. I have gone through your information an...       HC            0
# 4  Hello. You can try to retract foreskin daily d...       HC            0
# 5  Hello. Avoid raw cabbage, cauliflower, brocoll...       HC            0
# 6  Hi. With the symptoms I feel sorry for your he...       HC            0
# 7  Hi. I want to assure you not to worry as every...       HC            0
# 8  Hello. Staphylococcus aureus is a normal flora...       HC            0
# 9  Hi. Your blood pressure (BP) is absolutely nor...       HC            0

# %%
data['category'].value_counts()
# Out:
# category
# HC    400
# TC    400
# EC    260
# BA    145
# Name: count, dtype: int64

# %%
label_mapping = {
    'HC': 'Medical',
    'TC': 'Telecom',
    'BA': 'Banking',
    'EC': 'Ecommerce'
}

# Replace the labels
data['category'] = data['category'].replace(label_mapping)

print(data)
# Out:
#       Unnamed: 0                                             prompt  \
# 0            240  Hi doctor,I am just wondering what is abutting...
# 1            620  Hello doctor, I have a stiffness of neck and p...
# 2           1208  Hi doctor, I am a 26 year old male. I am 5 fee...
# 3           1388  Hi doctor, I am a 26 year old male. I am 5 fee...
# 4           1828  Hello doctor, I am a 24-year-old male. I am af...
# ...          ...                                                ...
# 1200      283316  Can I get help with understanding my account s...
# 1201      283317  What should I do if I have a question about my...
# 1202      283318  What are your policies on account inactivity f...
# 1203      283319                                                 Hi
# 1204      283320                        Tell me about your services
#
#                                                response category  category_id
# 0     Hi. I have gone through your query with dilige...  Medical            0
# 1     Hello. From your symptoms, it seems like fibro...  Medical            0
# 2     Hello. I have gone through your information an...  Medical            0
# 3     Hello. I have gone through your information an...  Medical            0
# 4     Hello. You can try to retract foreskin daily d...  Medical            0
# ...                                                 ...      ...          ...
# 1200  Yes, you can get help with understanding your ...  Banking            3
# 1201  For questions about your loan, contact our loa...  Banking            3
# 1202  Account inactivity fees and policies are detai...  Banking            3
# 1203  Hi there, My name is Alice from XYZ Bank. How ...  Banking            3
# 1204  We are leading international bank, having bran...  Banking            3
#
# [1205 rows x 5 columns]

# %%
from datasets import Dataset
data = Dataset.from_pandas(data)


print(data)
# Out:
# Dataset({
#     features: ['Unnamed: 0', 'prompt', 'response', 'category', 'category_id'],
#     num_rows: 1205
# })

# %%
columns_to_remove = ["Unnamed: 0", "category_id"]  # Replace with the names of the columns you want to drop
data = data.map(lambda x: x, remove_columns=columns_to_remove)
print(data)
# Out:
# Map:   0%|          | 0/1205 [00:00<?, ? examples/s]
# Dataset({
#     features: ['prompt', 'response', 'category'],
#     num_rows: 1205
# })

# %%
compute_dtype = getattr(torch, 'float16')

bnbconfig = BitsAndBytesConfig(
    load_in_4bit = True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=True,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name, 
    quantization_config=bnbconfig, 
    torch_dtype=compute_dtype, 
    low_cpu_mem_usage=True,
    #trust_remote_code=True,
)
# Out:
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/16.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
model, tokenizer = setup_chat_format(model, tokenizer)
# Out:
# tokenizer_config.json:   0%|          | 0.00/3.44k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/599 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-b9fcf69e8db4> in <cell line: 2>()
#       1 tokenizer = AutoTokenizer.from_pretrained(model_name)
# ----> 2 model, tokenizer = setup_chat_format(model, tokenizer)
#
# /usr/local/lib/python3.10/dist-packages/trl/models/utils.py in setup_chat_format(model, tokenizer, format, resize_to_multiple_of)
#      99     # check if model already had a chat template
#     100     if tokenizer.chat_template is not None:
# --> 101         raise ValueError(
#     102             "Chat template is already added to the tokenizer. If you want to overwrite it, please set it to None"
#     103         )
#
# ValueError: Chat template is already added to the tokenizer. If you want to overwrite it, please set it to None

# %%
def format_chat_template(row):
    row_json = [{"role": "user", "content": row["prompt"]},
               {"role": "assistant", "content": row['response']}]
    row["text"] = tokenizer.apply_chat_template(row_json, tokenize=False)
    return row

dataset = data.map(
    format_chat_template,
    num_proc=4,
)

dataset['text'][5]
# Out:
# Map (num_proc=4):   0%|          | 0/1205 [00:00<?, ? examples/s]
# '<|user|>\nHello doctor, I had a sudden weight gain. Are there any foods that should be avoided either at certain times of the day or all together while taking Levothyroxine to treat an underactive thyroid?<|end|>\n<|assistant|>\nHello. Avoid raw cabbage, cauliflower, brocolli, soy and soy products like soy sauce, soy milk, tofu, strawberry, walnut, spinach, and brussel sprouts. Do not take any meals or drink except plain water for atleast 45 minutes after taking medication. Avoid taking acidity-causing foods, calcium and iron supplements with the medicine.<|end|>\n<|endoftext|>'

# %%
training_arguments = TrainingArguments(
    output_dir="RANDOM_CHATBOT",
    num_train_epochs=1,
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8,
    optim="paged_adamw_32bit",
    save_steps=0,
    logging_steps=15,
    learning_rate=5e-4,
    weight_decay=0.001,
    fp16=True,
    max_grad_norm=0.3,
    warmup_ratio=0.03,
    lr_scheduler_type="cosine",
    report_to="none",
)

# %%
from peft import get_peft_model, prepare_model_for_kbit_training, PeftModel
peft_config = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=['up_proj', 'down_proj', 'gate_proj', 'k_proj', 'q_proj', 'v_proj', 'o_proj']
)
model = get_peft_model(model, peft_config)

# %%
trainer = SFTTrainer(
    model = model, 
    train_dataset = dataset, 
    peft_config = peft_config, 
    tokenizer = tokenizer, 
    args = training_arguments,
    #dataset_text_field="generated_prompt",
)

trainer.train()
# Out:
# <ipython-input-17-5bb1f8203460>:1: FutureWarning: `tokenizer` is deprecated and removed starting from version 0.16.0 for `SFTTrainer.__init__`. Use `processing_class` instead.
#   trainer = SFTTrainer(
# Map:   0%|          | 0/1205 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:300: UserWarning: You passed a processing_class with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `processing_class.padding_side = 'right'` to your code.
#   warnings.warn(
#     <div>
#
#       <progress value='150' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [150/150 11:16, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>15</td>
#       <td>15.608700</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>11.368000</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>11.801000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>10.890600</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>11.203200</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>10.709700</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>11.768900</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>9.921300</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>9.570400</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>9.216700</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=150, training_loss=11.205844421386718, metrics={'train_runtime': 681.3444, 'train_samples_per_second': 1.769, 'train_steps_per_second': 0.22, 'total_flos': 3956956039956480.0, 'train_loss': 11.205844421386718, 'epoch': 0.995850622406639})

# %%
messages = [
    {
        "role": "user",
        "content": "I am have been charged for 40gb of data while i used 30gb data only. Please resolve this issue"
    }
]

prompt = tokenizer.apply_chat_template(messages, tokenize=False, 
                                       add_generation_prompt=True)

inputs = tokenizer(prompt, return_tensors='pt', padding=True, 
                   truncation=True).to("cuda")

outputs = model.generate(**inputs, max_length=150, 
                         num_return_sequences=1)

text = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(text.split("assistant")[-1])
# Out:
# I am have been charged for 40gb of data while i used 30gb data only. Please resolve this issue To address the issue of being charged for more data than you have used, please adhere to the following steps:
#
# 1. Log in to your account on {{WEBSITE_URL}}.
# 2. Navigate to the {{DATA_SECTION}} section.
# 3. Select the {{INFORM_OPTION}} option.
# 4. Choose the bill or usage details you wish to dispute.
# 5. Provide a detailed explanation for the dispute.
# 6. Submit the dispute form.
#
# Our team will review your submission and get back to you within

# %%
model_dir = "Phi3.5-Combined-ChatBot"
trainer.model.save_pretrained(model_dir)
trainer.tokenizer.save_pretrained(model_dir)
# Out:
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.
# ('Phi3.5-Combined-ChatBot/tokenizer_config.json',
#  'Phi3.5-Combined-ChatBot/special_tokens_map.json',
#  'Phi3.5-Combined-ChatBot/tokenizer.model',
#  'Phi3.5-Combined-ChatBot/added_tokens.json',
#  'Phi3.5-Combined-ChatBot/tokenizer.json')
